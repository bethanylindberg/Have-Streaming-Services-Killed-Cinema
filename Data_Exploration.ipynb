# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

moviefile = pd.read_csv('.\\cleaned_data\\omdb_movies_cleaned.csv')

moviedata = pd.DataFrame(moviefile)

moviedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16970 entries, 0 to 16969
# Data columns (total 12 columns):
# Title          16970 non-null object
# Year           16970 non-null int64
# Genre          16964 non-null object
# Country        16967 non-null object
# RT_Ratings     16970 non-null object
# Metascore      11351 non-null float64
# imdbRating     16970 non-null float64
# imdbVotes      16969 non-null object
# Type           16970 non-null object
# Production     15847 non-null object
# RT_Ratings2    16970 non-null int64
# imdbRating2    16970 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.6+ MB

# %%
moviedatayear = moviedata.query("Year>1989").query("Year<2017")

# %%
x_axis = moviedatayear.groupby('Year')['Year'].max()
rt = moviedatayear.groupby('Year')["RT_Ratings2"].mean()
imdb = moviedatayear.groupby('Year')["imdbRating2"].mean()

plt.plot(x_axis, rt)
plt.plot(x_axis, imdb)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
